# %% [markdown]
# # Convert snippets to conversations
#
# ## first pass:
#
#  - [x] get posts + comments
#  - [x] append toplevel posts and comments
#  - [x] groupby root_id
#  - [x] sort by root_id, parent_id, time?
#  - [x] make a single row per post + comments with display text: f"@{post_author}:{post_text} \n @{reply_author}: {reply_text} etc." up to x00 words.
#  - [x] Save on local_artifacts
#  - [x] show in prodigy
#
# ## second pass?
#
#  Get a better way to annotate specific parts of the text? spancat? ccreate custom

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datetime

import pandas as pd
import tentaclio
import spacy

from phoenix.common import artifacts, run_params, utils

# %%
utils.setup_notebook_output()
utils.setup_notebook_logging()

# %%
# Files
posts_df_path = f"{artifacts.urls.get_local()}/prodigy/reddit_posts_2019_5.csv"
comments_df_path = f"{artifacts.urls.get_local()}/prodigy/reddit_comments_2019_5.csv"
twitter_df_path = f"{artifacts.urls.get_local()}/prodigy/2022-6.parquet"
output_path = f"{artifacts.urls.get_local()}/prodigy/reddit_conversations.csv"
twitter_output_path = f"{artifacts.urls.get_local()}/prodigy/twitter_2022-6_conversations.csv"

with tentaclio.open(posts_df_path, "r") as fb:
    posts_df = pd.read_csv(fb)
    
with tentaclio.open(comments_df_path, "r") as fb:
    comments_df = pd.read_csv(fb)

# %%
df = artifacts.dataframes.get(twitter_df_path).dataframe

# %%
# load AraVec Spacy model
nlp = spacy.load("./spacy.aravec.model/")

# %%
import gensim
import re
import spacy

# Clean/Normalize Arabic Text
def clean_str(text):
    search = ["أ","إ","آ","ة","_","-","/",".","،"," و "," يا ",'"',"ـ","'","ى","\\",'\n', '\t','&quot;','?','؟','!']
    replace = ["ا","ا","ا","ه"," "," ","","",""," و"," يا","","","","ي","",' ', ' ',' ',' ? ',' ؟ ',' ! ']
    
    #remove tashkeel
    p_tashkeel = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    text = re.sub(p_tashkeel,"", text)
    
    #remove longation
    p_longation = re.compile(r'(.)\1+')
    subst = r"\1\1"
    text = re.sub(p_longation, subst, text)
    
    text = text.replace('وو', 'و')
    text = text.replace('يي', 'ي')
    text = text.replace('اا', 'ا')
    
    for i in range(0, len(search)):
        text = text.replace(search[i], replace[i])
    
    #trim    
    text = text.strip()

    return text

# %%
# Define the preprocessing Class
class Preprocessor:
    def __init__(self, tokenizer, **cfg):
        self.tokenizer = tokenizer

    def __call__(self, text):
        preprocessed = clean_str(text)
        return self.tokenizer(preprocessed)

# %%
# Apply the `Preprocessor` Class
nlp.tokenizer = Preprocessor(nlp.tokenizer)

# %%
df[102710:102720]

# %%
test_df = df[:5].copy()

# %%
oov_words = []
is_oov = []
sum_tokens = []
for doc in nlp.pipe(df["text"].astype('unicode').values):
    is_oov.append(sum(n.is_oov for n in doc if not str.isascii(str(n))))
    sum_tokens.append(len(doc))
    oov_words.append(" ".join([str(n) for n in doc if n.is_oov and not str.isascii(str(n)) ]))

# %%
oov_words = []
for doc in nlp.pipe(df["text"].astype('unicode').values):
    oov_words.append(" ".join([str(n) for n in doc if n.is_oov and not str.isascii(str(n)) ]))

# %%
oov_words
# Out:
# ['جريوال تحتفظون',
#  '',
#  '',
#  '',
#  '« « «',
#  '',
#  'ب«جدري',
#  'يااهل فوليتم لارذل المفحوصين وشاورمجيه للعوره فاستاسد القطرجالكم القوراب',
#  '',
#  '',
#  'مشروعن بتخففوا',
#  '',
#  '',
#  'ستزود هيمارس',
#  'جافلين وستينغر',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'كوزو اوكاموتو',
#  '',
#  '',
#  '',
#  '',
#  'ممافيدلك بيعجبكن ياانتو منكن',
#  'جعجعات',
#  'نعطيهن لتتبلور',
#  'سنتردد',
#  '',
#  '٣٠ ٩ الحزب',
#  'غروندبرغ',
#  'مصر ل250 و150',
#  '« طاجيكستان',
#  '',
#  '',
#  '',
#  'didn’t',
#  '«',
#  'مصر «',
#  'يحميلنا ️Elias',
#  'للرابح والطاغي 🧡',
#  'وانغلاق',
#  'الاقتصادي+',
#  '«',
#  'لاسيره',
#  'والعونيه',
#  'باكستان و«طالبان',
#  'كزدوره',
#  '',
#  '«',
#  'ستزود هيمارس',
#  'سوری کے کو اسلامی ٹچ والے مشورے مسلمہ کے لیڈر کے چہرے پہ پڑا اتار دیا فوبیا ڈرامہ تقریریں فلاپ کر دیں میڈیا ٹیم پشاور منجانب جمیل داودزئی',
#  '',
#  'ل80',
#  '',
#  '« اللاافق',
#  '',
#  '',
#  'وو',
#  '🤦',
#  '',
#  'لعقاراتها الجنسيه',
#  '',
#  'عحسابن بيوقفني وبفكرو',
#  '',
#  'ديكنسن تناقضاتنا',
#  'التغيري الحزب اليهودانت الطاءفيه الطاءفيه اسقطوهماما طاءفي',
#  'التغيري الحزب اليهودانت الطاءفيه الطاءفيه اسقطوهماما طاءفي',
#  'المكسيك و20 المكسيك',
#  'التغيري الحزب اليهودانت الطاءفيه الطاءفيه اسقطوهماما طاءفي',
#  '«',
#  'لخصوم « حواط',
#  '',
#  '',
#  'ايفانوفو',
#  'نكسه للاكثريه',
#  'التغيرين \u200a وتريث',
#  'يوبيلها',
#  'و#جنبلاط',
#  'بعملات',
#  'و#العراق و#لبنان و#اليمن طاردو قسد',
#  '',
#  '',
#  '«',
#  '«',
#  '٤٠ طيروهم مصرياتك ٣٠',
#  'والمطرقه والمنجل',
#  '٣٠ ٩ الحزب',
#  'سيتخذها',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'وحزب للحليف للحزب',
#  '',
#  'الحزب حواط القواتين',
#  'الحزب ويتفاوض',
#  'سوری کے کو اسلامی ٹچ والے مشورے مسلمہ کے لیڈر کے چہرے پہ پڑا اتار دیا فوبیا',
#  '«',
#  'واستخباراته فصنفهم وبلافايده',
#  'واستخباراته فصنفهم وبلافايده',
#  '« «',
#  '',
#  'اكثريتها',
#  'اقترابها « لوغانسك',
#  '',
#  '',
#  'نكسه للاكثريه',
#  '',
#  '',
#  '',
#  '٨ ستنتقم لهزيمتها',
#  '',
#  '',
#  '',
#  'انترفاكس ايفانوفو',
#  'انترفاكس',
#  '',
#  '',
#  '',
#  '',
#  'شاغبوا',
#  '',
#  'وباسيل',
#  '',
#  '',
#  '',
#  'لالانباء التغيرين المترابطه والمتفاهمه انعكس \xa0 ',
#  '',
#  'لالانباء السكاف',
#  'الحزب',
#  'ب«انتهاك واعرافها',
#  'اكثريتها وباسيل',
#  'التغيرين',
#  '« الاكثريات',
#  'مصر',
#  '',
#  'الملغاه فرزها',
#  'ال65',
#  'وحزب للحليف للحزب',
#  'وتشظي',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'وستريدا',
#  'بالفايكات',
#  '',
#  'التاكسي',
#  '',
#  'اكثريتها',
#  'البنك',
#  '٢٤ و3',
#  'وفازلين',
#  'مصيريه',
#  '',
#  '« مرلين',
#  '',
#  '',
#  'ومخاض',
#  'راكيل',
#  '',
#  'مستعاد',
#  'منجيره',
#  'مستغبي مناصرينو واتباعو للائحتو وبيسوا فرنك ٥٠٠ هربها يااغبيا',
#  'اوعزت ل«نواب',
#  'لازملك خرفك يابيك لحليف صوتولو',
#  'ال24',
#  'ديبايت',
#  'اوسيتيا',
#  '',
#  'فجورك للائحتك',
#  'ديبايت',
#  '',
#  '',
#  'مصرياتكن همكن تدعسوا',
#  'و2019',
#  'مصرف',
#  '٢٤',
#  '',
#  '',
#  '',
#  'ستنتقم',
#  'انعكس',
#  'الولادكم يامطايا يازبال حزب',
#  'الولادكم يامطايا يازبال حزب',
#  'الولادكم يامطايا يازبال حزب',
#  '',
#  '',
#  'العادلون',
#  'مركت حزب',
#  '',
#  '',
#  '',
#  '',
#  'رئاسات',
#  '',
#  '',
#  '',
#  'بونجورك',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'اكثريته',
#  'ستزود هيمارس',
#  '',
#  '',
#  'و20 المكسيك',
#  '',
#  'زحفوا عمعراب 🤣 🤣',
#  '',
#  '',
#  '',
#  'سنزود',
#  'وyves',
#  '',
#  '',
#  'يساط بالسياسات طبعيتي والمتشككه',
#  '',
#  '',
#  '٢٤ و3',
#  'صباححو',
#  '',
#  'بونجوك',
#  'سنزود',
#  'مصيريه',
#  '',
#  'جنرالها',
#  'علیکروح علیک کرامت',
#  '',
#  '',
#  'اتتخبوه 🤣 🤣',
#  'هناك',
#  '',
#  '',
#  '',
#  '',
#  'لالجمهوريه',
#  'لالجمهوريه والتغيرين ومكتملا',
#  'قواتيه',
#  'وشعبويه ومصلحه',
#  'ستزود هيمارس',
#  'سید که اسرائیل عنکبوت الرضاییم',
#  '',
#  'بتخايل',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'وسنابلنا',
#  '',
#  'مصادر ل«الجمهوريه',
#  '',
#  'مصادر لالجمهوريه والمداولات',
#  '',
#  '',
#  'سايكس',
#  '',
#  '',
#  'بونجوك',
#  '',
#  '',
#  'و#نادين',
#  'بونجورك',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'مشهديه يعكس وبقانون',
#  '',
#  'زيلينسكي و100',
#  '',
#  'زيلينسكي و100 ديبايت',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'مركت حزب',
#  'مركت حزب',
#  '🇱 🇧 Premières',
#  '٨ وبسين بتصوتله',
#  '',
#  'بتقروا بيكتبولكن',
#  '',
#  '',
#  'البنك',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'زيلينسكي و100',
#  '',
#  'حمصي',
#  'التغيرين',
#  '',
#  'بالروضي',
#  'ديبايت',
#  '',
#  '',
#  '',
#  '« لخصوم ياحبوب « يهيكل',
#  '',
#  '🤣 🤣',
#  '',
#  '«',
#  '🤣',
#  'والتعوذ حزب',
#  '🤣 🤣',
#  '🤣 🤣',
#  'ديبايت',
#  '',
#  '',
#  'مدبرس مشلشين',
#  '',
#  'وفرعنه حزب',
#  '',
#  'التغيرين السيادين اختصاصين',
#  '',
#  'والخازن ووليم',
#  '',
#  'الفيلقيه',
#  '📂 لخصوم لخصوم و#القوات «',
#  'n’y défaillante d’engager réformes puisqu’elle n’acceptera',
#  '',
#  '« تغيريو « وyves',
#  '',
#  'مصرف',
#  '🥰',
#  '',
#  'اوقحك الاكتريه ٢٠٠٥ ٢٠٠٥',
#  'زيلينسكي و100',
#  '🦋',
#  'بالرص',
#  '',
#  '',
#  '🥞',
#  '🤷 🏽',
#  '',
#  'الخيرᅠ',
#  '',
#  'مااجمل',
#  '',
#  'واناملك تتنمل',
#  'يستفزونك بنجوركم',
#  '',
#  'الخيرᅠ',
#  'هناك وهناك',
#  'بشفتاي',
#  '',
#  'ظنكم',
#  '',
#  '',
#  '🤣 🤣',
#  'ومتباركين',
#  'ولتباهي بفاطم جلالا',
#  '',
#  '',
#  'يومابعد فتانس',
#  '',
#  'البزري',
#  '',
#  '',
#  '',
#  '\xa0\xa0    \xa0\xa0 ',
#  '\u200b﴿ مستبشرون \u200b•• مجموعاتنا',
#  'ديراني',
#  '',
#  '🤲',
#  'توسلوا',
#  'سياسياهداه ولوحدته',
#  'يمرقو',
#  '',
#  'القصيفي',
#  '',
#  '',
#  '\xa0  \xa0  🛢 ⛽ \xa0 ',
#  'وبشمس طٰه 🪐',
#  'الجنسين',
#  'حزب ويتشلت',
#  '',
#  'زيلينسكي و100',
#  'زاعم',
#  'للبتول فبقم لاحٙ',
#  'ياايها ؛ بعناياتك',
#  'فمثاليته',
#  'ويدعني',
#  '',
#  'انكسر',
#  'ياابا',
#  'وسنابلنا',
#  'لتجميعها',
#  'بعزيزه منك ؛ متبا',
#  '',
#  'بمعصومه',
#  '١ذوالقعده١٤٤٣ ١٦٢٠٢٢',
#  'حزب',
#  'ولتباهي بفاطم فبذي',
#  'فڪرت',
#  '',
#  '',
#  'كظلمه يونس(ع)في',
#  '',
#  'قدرالائتمان سلامهالشعوب يؤخذبنصائحها منظمهالصحهالعالميهدورا اجrام',
#  '',
#  'لامسوغات ومرفوضه',
#  'الاسراربالسيطره ازوفستال الغامضهفي',
#  'ياامي',
#  'كسر هذالسافل واقفاوبقي',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'سرافيس مصدر',
#  '',
#  'الحمصي',
#  '',
#  '',
#  'بشفاعتها',
#  '',
#  '',
#  'تؤدكم',
#  'الغذائيوالحاق المتدف',
#  '',
#  '',
#  'نخطها العكس نكتبها',
#  '',
#  '🇾 🇪',
#  'لحزب مصطفي',
#  'ب456',
#  '؛ ؛ ؛ المبيته',
#  '٢٤',
#  '؛ ؛ والتاسيس',
#  '؛ ؛ بادواته',
#  '؛ ؛ للوسائل والتكت',
#  '؛ ؛',
#  'الاجتماعيهذا الوطنيهكانت',
#  'الحلبوسي',
#  '',
#  'مصطفي',
#  'مصطفي',
#  '',
#  '',
#  '',
#  'ستنتقم لهزيمتها',
#  '',
#  '',
#  'مصطفي',
#  'فيهفسمع',
#  'مصطفي',
#  'بالفيديوحكومه',
#  'يامؤمنين هناك انتضروا يحيي',
#  'يامؤمنين الدريهمي',
#  'المشاط',
#  'يامؤمنين الدريهمي',
#  'يامؤمنين الدريهمي',
#  'يامؤمنين الدريهمي',
#  'راعب بعينيك',
#  '',
#  'بامكانك المقدستين',
#  '🇸 🇾 🇵 🇸',
#  '🇸 🇾 🇸 🇾',
#  '',
#  'ولعاني بمعراب 🥺 🤭',
#  '',
#  '🇺 🇸 🇺 🇦',
#  'باعماقكم',
#  '',
#  '',
#  'عطوركم',
#  '',
#  '',
#  '',
#  '',
#  'بتلبق',
#  '',
#  '؛ 🏾',
#  'ياامل',
#  'وينتصر#غاده 🧡',
#  'يخامرها الخيرᅠ',
#  'وقائعها واستوقد',
#  'المصداقيه',
#  'هناك',
#  'يامحراب',
#  'مستوحشا ياساكنين',
#  'بشقشقه يتجل',
#  'قانصوه لخصوم و#القوات',
#  '',
#  '',
#  'مصاريع',
#  'ياباصالح',
#  'وفحوي الرسالهفهو لماتعهد بهبايدنباعادهافتتاح القنصليهلامريكيهفي الشرقيهوالتي اغلقهابايدن عام2018',
#  'الاسrائيلي ماعرفب الاعلاموالمبالغه الصhيوني',
#  'الرجال(#حكام التطبيع)ادانوا الصhيونيهعلي يجرؤواعلي ادانهخط',
#  '',
#  '',
#  'اوكرانياوجنوبها زيلنسكي',
#  'حrبه سياسهالانهاكوالتاكل البطيءبدلا الحrب الصاعقهوالمدمرهالتي يجيدهاوالتي',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'المحصنون',
#  '',
#  '',
#  'نكون',
#  '',
#  'تبکيك لتجاهلها',
#  'كشفونا وجدين',
#  '',
#  '',
#  'ثقتكمتلبيتكم',
#  '',
#  '',
#  'ولازمنا',
#  'خارطته وجثي',
#  'حجمت',
#  '',
#  'التلکاني الگاك',
#  '',
#  'لانك',
#  'عالمعارك',
#  'م̷ن 🦋',
#  'تكسوك تنكر لايتنكر',
#  'ياايها',
#  'عالتيار',
#  '',
#  '',
#  '🥀',
#  'اكثريتين',
#  '',
#  '',
#  'ويتشلت الحزب وتباحث ديبايت',
#  'جمبلاط عالسوشيل مستغبي حزبه',
#  '',
#  'ستنتقم لهزيمتها',
#  '',
#  '',
#  '',
#  '',
#  'وجندوه',
#  'و#روسيا',
#  '',
#  '',
#  'سيناتوره',
#  '',
#  '',
#  '',
#  'واطرقوا',
#  '',
#  '٨',
#  '',
#  '',
#  '',
#  'بحقهافله قميا اسمی ولمراجعنا',
#  '',
#  'قولويه',
#  'PLA’s',
#  'وراسنه',
#  '',
#  'التغيرين والNGOs',
#  '',
#  'نكسه للاكثريه',
#  '',
#  'عالتيار',
#  '',
#  'بي1 بمركبات طرازماردر',
#  'Kyiv’s',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '🤦 🏻\u200d 🤣',
#  '',
#  'عقيص تظهير',
#  '',
#  'ديبايت',
#  '٢٠١٩',
#  '',
#  '\U0001f979',
#  'لدولار',
#  '',
#  '',
#  'وحزب للحليف للحزب',
#  '',
#  '',
#  'ماراتونيه',
#  '',
#  '',
#  '« قبان اغلبيتين',
#  'ديبايت',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ضبيه انطلياس ديبايت',
#  'جعجعوا',
#  '',
#  'ديبايت',
#  'بكراراكيد بعطلوا',
#  'الضبيه انطلياس نهرالموت',
#  'ضبيه انطلياس',
#  'مصادر لالديار حواط القواتين',
#  '',
#  'مصادر لالديار',
#  'لالديار البصم والتسويات والمحاصصه وسنكون اتفاقاتهم ومصلحه',
#  '',
#  '',
#  'مصادر لالديار المجلسيه',
#  '',
#  '',
#  'المصارف مصرف',
#  '',
#  'ضبيه انطلياس',
#  '',
#  'لصوتت خفوها شغلتوا ٦٠ احزابكن وطائفيتكن تنفعكن',
#  '',
#  'يارلمي',
#  'شولتس باجبارها',
#  'يااحبه',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'تناقضاتها',
#  '',
#  '\u200bعمليه طعن\u200b',
#  'البزري',
#  '',
#  'و31300 للمبيع',
#  'لتكليفها',
#  '',
#  'تميم🥲🥲',
#  'الكبوشيه',
#  '',
#  'وبالشحاده ال٦٣ تيصيروا',
#  '',
#  '',
#  '',
#  'و#بوسطن سلتيكس',
#  '',
#  '',
#  '',
#  '',
#  'Scholz’s',
#  '',
#  '\u200bالاول باكثريه 125صوتا',
#  '️Biden doesn’t',
#  '',
#  'اكثريته',
#  '️Zelensky',
#  'We’re',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ديبايت',
#  '',
#  '«',
#  '',
#  'مصالحها ومترابطه',
#  '',
#  '🦋',
#  'الغصيب',
#  '',
#  '',
#  'وابقيتك',
#  '',
#  '',
#  '',
#  '',
#  'بقصيدته',
#  '',
#  '',
#  '',
#  'عينيك 🖤',
#  '',
#  'الديلم',
#  'ياالل',
#  'وتشاركونا',
#  '',
#  '',
#  '',
#  'لوغانسك سيفيرودونيتسك',
#  '',
#  '',
#  '🤍',
#  '',
#  'يخسر🤍 🤍',
#  '',
#  'ونرنم',
#  '﮼فاستجاب ﮼لهم ﮼ربهم',
#  'عنك يارؤوف',
#  'يجعجع',
#  'المصارف مصرف',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'منقحه',
#  '',
#  '',
#  '',
#  '',
#  'البنك',
#  '',
#  '',
#  'وراسنه',
#  'المكسيك',
#  'بيلوسي',
#  'ال«كيتو',
#  '',
#  '',
#  'و#روسيا',
#  '',
#  '',
#  '🤷 🏽',
#  'الخيرᅠ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'انك انك انك انك',
#  'المتفانيه اخلاصها',
#  'التوسلتذكروا',
#  'وشكويٰ دﻣتم ﻧلجٲ اليڪم هموﻣنا بڪلم',
#  '',
#  '',
#  'و”الزرعه',
#  '',
#  '',
#  'مغمس بعرقهم ودماءهم',
#  'ملغاه',
#  'التغيرين وسيدتهم كذبيان ملغاه',
#  'بمعصومه',
#  'رزف',
#  'للثكلي',
#  'لعلع',
#  'يازمباوي يااقرع عنك',
#  'لنواح كابتكون وقلقاس 🤣 🤣 🤣 ملغاه',
#  'ملغاه',
#  '',
#  'احيي',
#  '',
#  'الحزب ٢٠١١',
#  '',
#  'ومنقدر',
#  '',
#  '',
#  'يتمخض المهاجرين',
#  'هيمارس ستزوده',
#  'يلزمكم تستعينوا',
#  'عقيص تظهير',
#  '',
#  '',
#  '',
#  '',
#  'وتكلل',
#  'يواتينا',
#  '⧼ ﺎللهʊ̤ بفاطمۃ ꫂ فاطࢪ ﺎلسما၄ 🥺 ⧽',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'كسره كسره كسره تكسر ٠*',
#  'المماحكات والمماحكات ستنتشل بصبيان شينكر وغلمان',
#  '١',
#  'كالمغتاب',
#  'لاتبعدهم والقوميات',
#  'ويخططوا',
#  '',
#  '',
#  'سيقتنع',
#  'للمصارف',
#  '',
#  '',
#  'ברח בני בנימין מקרב ירושלים',
#  '',
#  '',
#  'هناك هناك',
#  '',
#  'ولكانت',
#  'قلدنا',
#  'وبرکاته',
#  'مساکم للتنويهاخي',
#  '',
#  'دلاور سپاه پاسداران 🇮 🇷 السفينتين اليونانيتين',
#  'ستغادرون ستغادرون',
#  '️ال',
#  'نوقت',
#  'لحزب الحزب بزواريب',
#  'كيانكم',
#  '',
#  'سيؤذي سيظلم',
#  '',
#  '',
#  'سيتعديٰ فالاوليٰ الكسر',
#  '',
#  'مستهلكا',
#  'مسميٰ',
#  '',
#  'المقترنه',
#  '',
#  '',
#  'والمبيدات',
#  'المطبعين وذلهم واخزهم',
#  'فلاحياه تصهينوا',
#  '',
#  '',
#  '',
#  'بهيده',
#  '',
#  'لشهدنا بقيعا',
#  '️\u2069 اجلفناوقد قساهنطعن ونغدر جلادونفلا باردنقتل وندبر',
#  '🇺 🇦',
#  '٣٠ايار ١٩٩٦',
#  '',
#  '',
#  'ديبايت',
#  '',
#  '',
#  'مصاريع',
#  'الحسين(ع وحنجرته',
#  'هناك سيحبطك',
#  'سينعكس واخلاقياتك',
#  'يتطوران',
#  '',
#  'منشتريلوا تيتسلي',
#  'مصالحها و#العراق و#ايران',
#  '',
#  '',
#  '',
#  '١٤ ١٤ ٢٠٠٥ عطيتكن تتعملوا',
#  'حواط',
#  '',
#  'و20 المكسيك',
#  '',
#  '',
#  'و10',
#  '',
#  'سيفيرودونتسك',
#  '',
#  'بفتيك بالحامض',
#  '',
#  'سيفيرودونتسك ديبايت',
#  '🤣 🤣',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'المصريهوالجماعه ومصادر والاعلامينبعها « ل«الاخوان',
#  'حزب « وال«شيروكي ال«#مرسيدس',
#  'سيفيرودونتسك',
#  '',
#  'فالروعه وبذر ناكل فاللفظ',
#  '🤣 🤣',
#  '',
#  'ياابو',
#  'الحطبه تابيد ؛ ؛ تابيد',
#  '',
#  'حاطا 🤦 🏻\u200d',
#  'وراسنه',
#  'تنمرت',
#  'وحزب للحليف للحزب',
#  '',
#  'ب30 والطحين الاكسترا',
#  'سيحوزها',
#  '',
#  'تتنمر',
#  'البزري باتجاهه',
#  'المصارف مصرف',
#  '🤣 🤣',
#  'البزري ومناقشتنا والتغيرين بعلانيه',
#  '',
#  'وراسنه ديبايت',
#  'متركزه لوغانسك',
#  'واشكاليات',
#  'Israel’s',
#  '',
#  '',
#  'هناك بالمصداقيه والقادره',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'اغاظ التغيرين',
#  '',
#  '',
#  '',
#  'منهني منغمز ومنسلم منلعب يكسرنا',
#  '',
#  'السنوار وحزب واغتصاب واغضاب',
#  'السنوار وحزب واغتصاب واغضاب',
#  'وحزب ياخناس',
#  'تغنستبلعك ينبذك للونك',
#  '',
#  'اوماها',
#  '',
#  '« «',
#  'بلوكاته ديبايت',
#  'المعاكسه',
#  'ياحبوب',
#  '',
#  'ستزود هيمارس',
#  '',
#  '',
#  'و20 المكسيك',
#  'تقترع المصرف',
#  'ديبايت',
#  'عاملتلك ياكردي الحزب يكسر',
#  'عاملتلك ياكردي الحزب يكسر',
#  '🤣',
#  '',
#  '',
#  '',
#  'مساطر 🤦 🏻\u200d 🤣',
#  'و”شكرا',
#  'و«القوات اكثريتها',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'لهؤلاء(النواب التغيرين «',
#  '',
#  'الملغاه فرزها',
#  '',
#  'وحزب للحليف للحزب',
#  '',
#  '',
#  'سپریم کورٹ کے ججز کو خاندان کی حقیقت بلدیاتی سے ھوچکی ھوگی۔رتی ھے ھی',
#  '',
#  'ديبايت',
#  '',
#  'البوخاري عالنافوخ 🤣',
#  '',
#  '',
#  '',
#  'تستبطن منتزع ب«شرعيه « « مصالحها «',
#  '',
#  '« مرمل',
#  '',
#  'توضحت',
#  '',
#  '',
#  '« Même espérances démarrage législature sûrement l’Étoile',
#  'والانكماش',
#  '',
#  '',
#  '🤣',
#  '🤷 🏽',
#  '',
#  '🤣 🤣',
#  'واتوعد صيغتو وهودي ممثلينو هالاصبع يبعدن',
#  'مصره',
#  'رياشي وقواتين',
#  'وبتسعيره',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ديبايت',
#  '',
#  'جوصي',
#  ...]

# %%
df["num_oov"] = is_oov
df["num_tokens"] = sum_tokens

# %%
df["oov_words"] = oov_words

# %%
df["percentage_oov"] = df["num_oov"] / df["num_tokens"]

# %%
# within the text snippets, on average 5% of the tokens in the text snippets is out of vocabulary
# This is a relatively low number
df["percentage_oov"].describe()
# Out:
# count    102718.000000
# mean          0.052952
# std           0.076947
# min           0.000000
# 25%           0.000000
# 50%           0.035714
# 75%           0.076923
# max           0.909091
# Name: percentage_oov, dtype: float64

# %%
# There are many genuine arabic OOV words that we would want to doublecheck with an expert
# Such as "حزب", "ديبايت" , and "كاريش" but a lot of the OOV words are emoji's
df["oov_words"].str.split(expand=True).stack().value_counts()[:50]
# Out:
# «                4846
# حزب              3488
# ديبايت           2132
# 🤣                1630
# كاريش            1127
# الحزب            1101
# هناك              880
# ؛                 858
# هوكشتاين          686
# 🛑                 683
# مصر               671
# 🇸                 572
# وهناك             566
# 🇾                 562
# 🇱                 499
# 🇪                 457
# 🇧                 427
# 🖤                 416
# مصادر             408
# مينينديز          357
# 🤦                 354
# مصانع             354
# 🏻‍                345
# العقو             324
# مصدر              313
# زيلينسكي          305
# 🧡                 296
# انك               291
# 🇵                 285
# الشراونه          277
# مصرف              260
# 🤍                 260
# 🇮                 251
# منك               248
# 🥰                 245
# كوخافي            235
# سيفيرودونيتسك     230
# لmtv              220
# لالجديد           212
# المصارف           199
# الخيرᅠ            199
# قسد               196
# 🇺                 194
# ٢٩                191
# التغيرين          183
# مصلحه             182
# 🥀                 182
# لحزب              182
# المصري            176
# هوكستين           170
# dtype: int64
